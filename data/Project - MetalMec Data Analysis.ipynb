# %% [markdown]
# ## **Objetivo do Projeto**
#
# ---
#
# O projeto visa analisar dados de uma empresa fictícia da Indústria metalmecânica fornecedora Tier 2 do setor automotivo, do interior de São Paulo. Seu porte é de 220 funcionários, com 3 turnos e produção contínua.
#
# O processo analisado é referente a uma linha automatizada de usinagem CNC (Comando Numérico Computadorizado), para produção de eixos e componentes rotativos de precisão com controle dimensional rigoroso.
#
# Nesse processo, estamos analisando uma máquina responsável por tarefas como: Torneamento de precisãom, Controle de torque, Controle térmico e Operação em alta rotação.
#
# Os dados foram extraídos da fonte Kaggle Datasets.

# %% [markdown]
# ## **Características do processo:**
#
#
# ---
#
#
# Produção por ciclo de usinagem
#
# 1 hora representa um bloco produtivo agregado
#
# Taxa ideal de produção: 50 peças/hora
#
# Falhas geram parada de 60 minutos
#
# Após falha, ocorre troca corretiva de ferramenta

# %% [markdown]
# # **Problemática Atual da Empresa**
#
# ---
#
# ## Nos últimos 6 meses foram compilados relatórios que indicaram:
#
# - Aumento de 18% nas falhas não programadas
# - Crescimento no custo de manutenção corretiva
# - Queda na disponibilidade da máquina
# - Aumento no risco de atraso de entrega
#
# ## A diretoria observou queda no OEE da célula
#
# - Houve aumento de paradas não programadas
# - A produtividade média caiu abaixo da meta
# - O desgaste da ferramenta parece estar impactando o desempenho
#
# ## A meta corporativa é:
#
# - OEE ≥ 85%
#
# Atualmente suspeita-se que esteja abaixo disso.
#
#
# ---
#
#
# ## **Propor melhoria baseada em dados**
# A diretoria quer:
# - Reduzir falhas
# - Aumentar confiabilidade
# - Migrar de manutenção corretiva para preditiva

# %% [markdown]
# ## **Etapa 1: Importação e Carregamento dos Dados**
#
# ---
#
# Bibliotecas utilizadas/importadas:
# - Pandas & numpy: Coleta, limpeza, preparação e descrição dos dados
# - Matplotlib & Seaborn: Análise e visualização dos dados

# %%
#Importar bibliotecas, ler o arquivo e mostrar as 10 primeiras linhas (head)
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
database = pd.read_csv('https://raw.githubusercontent.com/Th3N1zz/MetalMec-Data-Analysis/refs/heads/main/Predictive_Maintenance_Realistic_Temporal.csv', sep =',')
database.head(10)
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
# 5    6     M14865    M                298.1                    308.6
# 6    7     L47186    L                298.1                    308.6
# 7    8     L47187    L                298.1                    308.6
# 8    9     M14868    M                298.3                    308.7
# 9   10     M14869    M                298.5                    309.0
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Machine failure  TWF  \
# 0                    1551         42.8         1.061810                0    0
# ...
